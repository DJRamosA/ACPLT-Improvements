# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from plotnine import *
from pathlib import Path

# %%
d_name = "Naturaleza"
data=pd.read_csv(f"../../../data/resultados_ep1_{d_name}.csv")
data["funca"]=data["model"]+"\n"+data["type"]
data["Min"] = data["mean"]-data["std"]
data["max"] = data["mean"]+data["std"]
data
# Out:
#        model   type      mean       std E-type            funca       Min  \
# 0         E5  Norm.  0.521217  0.001986  Train        E5\nNorm.  0.519231
# 1   Word2Vec  Norm.  0.505376  0.001844  Train  Word2Vec\nNorm.  0.503532
# 2      LaBSE  Norm.  0.473118  0.005900  Train     LaBSE\nNorm.  0.467218
# 3       BERT  Norm.  0.389689  0.003611  Train      BERT\nNorm.  0.386078
# 4     CANINE  Norm.  0.309236  0.001273  Train    CANINE\nNorm.  0.307963
# 5         E5  Lemm.  0.520352  0.006668  Train        E5\nLemm.  0.513684
# 6   Word2Vec  Lemm.  0.513152  0.004179  Train  Word2Vec\nLemm.  0.508974
# 7      LaBSE  Lemm.  0.475134  0.006991  Train     LaBSE\nLemm.  0.468143
# 8       BERT  Lemm.  0.384313  0.005107  Train      BERT\nLemm.  0.379206
# 9     CANINE  Lemm.  0.319796  0.002115  Train    CANINE\nLemm.  0.317681
# 10        E5  Norm.  0.399381  0.017814   Test        E5\nNorm.  0.381566
# 11  Word2Vec  Norm.  0.387864  0.009219   Test  Word2Vec\nNorm.  0.378645
# 12     LaBSE  Norm.  0.328727  0.011129   Test     LaBSE\nNorm.  0.317598
# 13      BERT  Norm.  0.211981  0.004936   Test      BERT\nNorm.  0.207045
# 14    CANINE  Norm.  0.137868  0.009326   Test    CANINE\nNorm.  0.128542
# 15        E5  Lemm.  0.389017  0.008448   Test        E5\nLemm.  0.380569
# 16  Word2Vec  Lemm.  0.379418  0.017574   Test  Word2Vec\nLemm.  0.361844
# 17     LaBSE  Lemm.  0.319507  0.017877   Test     LaBSE\nLemm.  0.301629
# 18      BERT  Lemm.  0.202768  0.016401   Test      BERT\nLemm.  0.186367
# 19    CANINE  Lemm.  0.149772  0.010406   Test    CANINE\nLemm.  0.139366
#
#          max
# 0   0.523203
# 1   0.507221
# 2   0.479018
# 3   0.393301
# 4   0.310508
# 5   0.527020
# 6   0.517331
# 7   0.482125
# 8   0.389420
# 9   0.321912
# 10  0.417195
# 11  0.397083
# 12  0.339855
# 13  0.216917
# 14  0.147194
# 15  0.397464
# 16  0.396992
# 17  0.337384
# 18  0.219170
# 19  0.160178

# %%
temp=(ggplot(data)+aes(x="funca",y="mean",color="E-type",shape="E-type",ymin="Min",ymax="max")+theme_bw()
+theme(legend_position=(0.925,0.2))
+geom_point(size=4)
+labs(title='', x="", y="Accuracy")
+theme(axis_text_y = element_text(size=15))+theme(axis_title_y = element_text(size=20))
+theme(axis_text_x = element_text(size=15))
+theme(title = element_text(size=25))
+theme(legend_title = element_text(size=20))+theme(legend_background = element_rect(color="black",size=0.5))
+theme(legend_text = element_text(size=15))
+geom_linerange(size=1)
+scale_color_manual(name = "Accuracy",values=["#D83232","#3837D9"])
+scale_shape_manual(name = "Accuracy",values = ["s",'o'])
)
temp.save(filename=f'../../../data/results/IMG/{d_name}_resultados_exp1.png',width=15, height=7)
temp
# Out:
# c:\Users\dra98\OneDrive\Documentos\Trabajo\Doctorado\Codigo\myvenv\lib\site-packages\plotnine\ggplot.py:615: PlotnineWarning: Saving 15 x 7 in image.
# c:\Users\dra98\OneDrive\Documentos\Trabajo\Doctorado\Codigo\myvenv\lib\site-packages\plotnine\ggplot.py:616: PlotnineWarning: Filename: ../../../data/results/IMG/Naturaleza_resultados_exp1.png
