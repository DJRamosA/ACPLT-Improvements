# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
matrix_cpn27_word2vec_norm = [
    ['ACPLT','n_clusters=750',0.547337120229136,0.004026013562288328,0.4007705433797259,0.008814725049141015],
    ['DecisionTrees','max_leaf_nodes=300',0.34629426935658014,0.00229185387650594,0.23673730151893646,0.009871468331581026],
    ['GaussianNB','var_smoothing=0.1',0.8709494343684824,0.004946626426246061,0.4680057344671006,0.010081770621857744],
    ['LinearSVC','C=1',0.5876870909143335,0.0039889107249719774,0.45727268252464215,0.006472143142911996]
]


matrix_cpn120_word2vec_norm = [
    ['ACPLT','n_clusters=1750',0.5871359744269495,0.0029883868184880096,0.5404219178740665,0.005093942556401926],
    ['DecisionTrees','max_leaf_nodes=1500',0.5013494765104267,0.0028024858644142697,0.43745340536902927,0.00944682556582543],
    ['GaussianNB','var_smoothing=10',0.6089631136707914,0.0014148079974893137,0.5376601588091002,0.007392443158172325],
    ['LinearSVC','C=1',0.7623650743090005,0.0021998956896611375,0.6607772865536683,0.007857881932707922]
]


matrix_cpn27_labse_norm = [
    ['ACPLT','n_clusters=550',0.43210814759282223,0.003249916816100426,0.3041736911837696,0.010154399934628838],
    ['DecisionTrees','max_leaf_nodes=400',0.3956562190632719,0.0021328284245052454,0.2049458753266144,0.01853588532522059],
    ['GaussianNB','var_smoothing=0.1',0.9331208698967414,0.001462839836695606,0.495952237385608,0.015854490813157433],
    ['LinearSVC','C=1.0',0.63866916563344,0.00361560629694802,0.480157431221261,0.00911425215647313]
]

matrix_cpn120_labse_norm = [
    ['ACPLT','n_clusters=1750',0.5693965376432413,0.0033510251045588083,0.5144052578217367,0.008248120942470842],
    ['DecisionTrees','max_leaf_nodes=1500',0.4791928295112794,0.0016768741734105564,0.39113109990367595,0.011228127196445756],
    ['GaussianNB','var_smoothing=1.0',0.5836053359377852,0.0029134039654515626,0.4933156238521564,0.005580629476325688],
    ['LinearSVC','C=1.0',0.7736944769700332,0.0030133103682522915,0.668089611018865,0.007843165235834115]
]
# aquí arriba los ultimos 2 mejoran bastante por lo que se podrían ejecutar más experimentos.

matrix_cpn27_labse_lemma = [
    ['ACPLT','n_clusters=550',0.44638571872527055,0.005422758942806614,0.3221948078051102,0.010539707220374658],
    ['DecisionTrees','max_leaf_nodes=300',0.3499394545204066,0.0033361039180194703,0.20555111182210845,0.01247590341739772],
    ['GaussianNB','var_smoothing=0.1',0.9313995943984699,0.0023183792171517273,0.503445397454356,0.01248130878516719],
    ['LinearSVC','C=1.0',0.6201901777790593,0.0045840152746345324,0.4773250638872139,0.01519778450713414]
]

matrix_cpn120_labse_lemma = [
    ['ACPLT','n_clusters=1750',0.5934754286321895,0.004935569283080325,0.542305152120395,0.009547155239371937],
    ['DecisionTrees','max_leaf_nodes=1500',0.5324269073888747,0.0023686245384220883,0.4602376541650279,0.009330085330093258],
    ['GaussianNB','var_smoothing=0.1',0.7476305651989436,0.0024140479713640247,0.6216111865135686,0.013241497388551179],
    ['LinearSVC','C=1.0',0.7657701758335582,0.0038476933399927142,0.6700039370819436,0.007555068235401887]
]

# CANINE RAW
matrix_cpn27_canine_raw = [
    ['ACPLT','n_clusters=550',0.2632139147596026,0.0020167423311687653,0.11806685289328064,0.007691700272963882],
    ['DecisionTrees','max_leaf_nodes=400',0.2697955140342615,0.005051151356820429,0.12920291727682548,0.006372803280026269],
    ['GaussianNB','var_smoothing=0.01',0.579587106612971,0.0040809960721638686,0.12130612948082153,0.009252408168993307],
    ['LinearSVC','C=0.1',0.3227523491889571,0.0066730700814616,0.1597838704781594,0.008433702047443507],
    ['XGBClassifier', 'max_leaves=10, n_estimators=19',0.45646875766266853,0.06930290278104582,0.10397114927483331,0.009915040716310972]
]

matrix_cpn120_canine_raw = [
    ['ACPLT','n_clusters=1750',0.3686762463792629,0.0027040200506138062,0.3004328475366248,0.010107916557592718],
    ['DecisionTrees','max_leaf_nodes=1500',0.36047734467442916,0.004283319685392838,0.2935912146631628,0.011832330095689951],
    ['GaussianNB','var_smoothing=0.01',0.324566921324992,0.005769228469013424,0.22037374402702709,0.006412982176095955],
    ['LinearSVC','C=0.1',0.4670396162195753,0.0026918711004331177,0.3710770652516418,0.0075425005005429775],
    ['XGBClassifier','max_leaves=10, n_estimators=1',0.06067405794171386,0.0027001867937581627,0.05601119559226346,0.0028638364280534445]
]


cols = ['model', 'best_param', 'train_mean', 'train_std', 'test_mean', 'test_std']

df_cpn27_w2v = pd.DataFrame(matrix_cpn27_word2vec_norm, columns=cols)
df_cpn120_w2v = pd.DataFrame(matrix_cpn120_word2vec_norm, columns=cols)
df_cpn27_labse = pd.DataFrame(matrix_cpn27_labse_norm, columns=cols)
df_cpn120_labse = pd.DataFrame(matrix_cpn120_labse_norm, columns=cols)
df_cpn27_labse_lemma = pd.DataFrame(matrix_cpn27_labse_lemma, columns=cols)
df_cpn120_labse_lemma = pd.DataFrame(matrix_cpn120_labse_lemma, columns=cols)
df_cpn27_canine_raw = pd.DataFrame(matrix_cpn27_canine_raw, columns=cols)
df_cpn120_canine_raw = pd.DataFrame(matrix_cpn120_canine_raw, columns=cols)

# %%
plt.figure(figsize=(7,5))
plt.errorbar(df_cpn27_w2v['model'], df_cpn27_w2v['train_mean'], yerr= df_cpn27_w2v['train_std'], color='blue',fmt ='o', alpha=0.3)
plt.errorbar(df_cpn27_w2v['model'], df_cpn27_w2v['test_mean'], yerr=df_cpn27_w2v['test_std'], color='red', fmt ='o', alpha=0.3)
plt.legend(['train', 'test'])
plt.ylim([0.0, 1.0])
plt.title('CPN27 Normalize Word2Vec')
plt.savefig(r'../data/results/IMG/CPN27_Norm_W2V_v2.png')

# %%
plt.figure(figsize=(7,5))
plt.errorbar(df_cpn120_w2v['model'], df_cpn120_w2v['train_mean'], yerr= df_cpn120_w2v['train_std'], color='blue',fmt ='o', alpha=0.3)
plt.errorbar(df_cpn120_w2v['model'], df_cpn120_w2v['test_mean'], yerr=df_cpn120_w2v['test_std'], color='red', fmt ='o', alpha=0.3)
plt.legend(['train', 'test'])
plt.ylim([0.0, 1.0])
plt.title('CPN120 Normalize Word2Vec')
plt.savefig(r'../data/results/IMG/CPN120_Norm_W2V_v2.png')

# %%
plt.figure(figsize=(7,5))
plt.errorbar(df_cpn27_labse['model'], df_cpn27_labse['train_mean'], yerr= df_cpn27_labse['train_std'], color='blue',fmt ='o', alpha=0.3)
plt.errorbar(df_cpn27_labse['model'], df_cpn27_labse['test_mean'], yerr=df_cpn27_labse['test_std'], color='red', fmt ='o', alpha=0.3)
plt.legend(['train', 'test'])
plt.ylim([0.0, 1.0])
plt.title('CPN27 Normalize LaBSE')
plt.savefig(r'../data/results/IMG/CPN27_Norm_LaBSE_v2.png')

# %%
plt.figure(figsize=(7,5))
plt.errorbar(df_cpn120_labse['model'], df_cpn120_labse['train_mean'], yerr= df_cpn120_labse['train_std'], color='blue',fmt ='o', alpha=0.3)
plt.errorbar(df_cpn120_labse['model'], df_cpn120_labse['test_mean'], yerr=df_cpn120_labse['test_std'], color='red', fmt ='o', alpha=0.3)
plt.legend(['train', 'test'])
plt.ylim([0.0, 1.0])
plt.title('CPN120 Normalize LaBSE')
plt.savefig(r'../data/results/IMG/CPN120_Norm_LaBSE_v2.png')

# %%
plt.figure(figsize=(7,5))
plt.errorbar(df_cpn27_labse_lemma['model'], df_cpn27_labse_lemma['train_mean'], yerr= df_cpn27_labse_lemma['train_std'], color='blue',fmt ='o', alpha=0.3)
plt.errorbar(df_cpn27_labse_lemma['model'], df_cpn27_labse_lemma['test_mean'], yerr=df_cpn27_labse_lemma['test_std'], color='red', fmt ='o', alpha=0.3)
plt.legend(['train', 'test'])
plt.ylim([0.0, 1.0])
plt.title('CPN27 Lemma LaBSE')
plt.savefig(r'../data/results/IMG/CPN27_Lemma_LaBSE_v2.png')

# %%
plt.figure(figsize=(7,5))
plt.errorbar(df_cpn120_labse_lemma['model'], df_cpn120_labse_lemma['train_mean'], yerr= df_cpn120_labse_lemma['train_std'], color='blue',fmt ='o', alpha=0.3)
plt.errorbar(df_cpn120_labse_lemma['model'], df_cpn120_labse_lemma['test_mean'], yerr=df_cpn120_labse_lemma['test_std'], color='red', fmt ='o', alpha=0.3)
plt.legend(['train', 'test'])
plt.ylim([0.0, 1.0])
plt.title('CPN120 Lemma LaBSE')
plt.savefig(r'../data/results/IMG/CPN120_Lemma_LaBSE_v2.png')

# %%
plt.figure(figsize=(7,5))
plt.errorbar(df_cpn27_canine_raw['model'], df_cpn27_canine_raw['train_mean'], yerr= df_cpn27_canine_raw['train_std'], color='blue',fmt ='o', alpha=0.3)
plt.errorbar(df_cpn27_canine_raw['model'], df_cpn27_canine_raw['test_mean'], yerr=df_cpn27_canine_raw['test_std'], color='red', fmt ='o', alpha=0.3)
plt.legend(['train', 'test'])
plt.ylim([0.0, 1.0])
plt.title('CPN27 CANINE Raw')
plt.savefig(r'../data/results/IMG/CPN27_canine_raw_v2.png')

# %%
plt.figure(figsize=(7,5))
plt.errorbar(df_cpn120_canine_raw['model'], df_cpn120_canine_raw['train_mean'], yerr= df_cpn120_canine_raw['train_std'], color='blue',fmt ='o', alpha=0.3)
plt.errorbar(df_cpn120_canine_raw['model'], df_cpn120_canine_raw['test_mean'], yerr=df_cpn120_canine_raw['test_std'], color='red', fmt ='o', alpha=0.3)
plt.legend(['train', 'test'])
plt.ylim([0.0, 1.0])
plt.title('CPN120 CANINE Raw')
plt.savefig(r'../data/results/IMG/CPN120_canine_raw_v2.png')

# %%
best_cpn27 = [df_cpn27_w2v.iloc[3,:],
              df_cpn27_labse.iloc[3,:],
              df_cpn27_labse_lemma.iloc[3,:],
              df_cpn27_canine_raw.iloc[3,:]]
best_cpn27 = np.vstack(best_cpn27)

best_cpn120 = [df_cpn120_w2v.iloc[3,:],
               df_cpn120_labse.iloc[3,:], 
               df_cpn120_labse_lemma.iloc[3,:],
               df_cpn120_canine_raw.iloc[3,:]]
best_cpn120 = np.vstack(best_cpn120)


models = ['Word2Vec_norm', 'LaBSE_norm', 'LaBSE_Lemma', 'CANINE_raw']


best_cpn27[:,0] = models
best_cpn120[:,0] = models

# %%
best_cpn27 = pd.DataFrame(np.vstack(best_cpn27), columns=cols)
best_cpn120 = pd.DataFrame(np.vstack(best_cpn120), columns=cols)

# %%
best_cpn120
# Out:
#            model best_param train_mean train_std test_mean  test_std
# 0  Word2Vec_norm        C=1   0.762365    0.0022  0.660777  0.007858
# 1     LaBSE_norm      C=1.0   0.773694  0.003013   0.66809  0.007843
# 2    LaBSE_Lemma      C=1.0    0.76577  0.003848  0.670004  0.007555
# 3     CANINE_raw      C=0.1    0.46704  0.002692  0.371077  0.007543

# %%
plt.figure(figsize=(8,4))
plt.errorbar(best_cpn27['model'], best_cpn27['train_mean'], yerr= best_cpn27['train_std'], color='blue',fmt ='o', alpha=0.3)
plt.errorbar(best_cpn27['model'], best_cpn27['test_mean'], yerr=best_cpn27['test_std'], color='red', fmt ='o', alpha=0.3)
plt.legend(['train', 'test'])
plt.ylim([0.0, 1.0])
plt.title('CPN27 Best model each embedding')
plt.savefig(r'../data/results/IMG/CPN27_BEST.png')

# %%
plt.figure(figsize=(8,4))
plt.errorbar(best_cpn120['model'], best_cpn120['train_mean'], yerr= best_cpn120['train_std'], color='blue',fmt ='o', alpha=0.3)
plt.errorbar(best_cpn120['model'], best_cpn120['test_mean'], yerr=best_cpn120['test_std'], color='red', fmt ='o', alpha=0.3)
plt.legend(['train', 'test'])
plt.ylim([0.0, 1.0])
plt.title('CPN120 Best model each embedding')
plt.savefig(r'../data/results/IMG/CPN120_BEST.png')
